# %% [markdown]
# <a href="https://colab.research.google.com/github/barna22/Deep-Learning-HW/blob/main/DL_nagyhf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 290 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 42.7 MB/s
# ...
#      |████████████████████████████████| 125 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 43.4 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 192 kB 57.0 MB/s
# ...
#      |████████████████████████████████| 160 kB 58.9 MB/s
# ...

# %%
from io import BytesIO
from PIL import Image

import datasets

def bytes_to_pil(example_batch):
    example_batch['img'] = [
        Image.open(BytesIO(b)) for b in example_batch.pop('img_bytes')
    ]
    return example_batch

ds = datasets.load_dataset('nateraw/fairface')
ds = ds.with_transform(bytes_to_pil)
# Out:
# Downloading:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Using custom data configuration default
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/514M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0M [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset fairface downloaded and prepared to /root/.cache/huggingface/datasets/nateraw___fairface)/default/0.0.0/9d7c8b446334b65d582e9a176cefe55c7a92dff164a02e433fe59b5dffdbfe36. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
train = ds['train']
print(train.shape)

# split val dataset into separate validation and test parts
val = ds['validation'][0:5000]
test = ds['validation'][5000:]

print("Validation dataset size: ", len(val['img']))
print("Test dataset size: ", len(test['img']))


# print funny images
val['img'][2]
# Out:
# (86744, 4)
# Validation dataset size:  5000
# Test dataset size:  5954
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FE22BBFCE50>

# %%
test['img'][18]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7FE22C99FC10>
